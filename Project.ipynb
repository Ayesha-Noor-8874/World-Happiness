# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayesha-Noor-8874/World-Happiness/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git config --global user.email "ayeshanoor8874@gmail.com"
# !git config --global user.name "Ayesha_Noor_8874"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
